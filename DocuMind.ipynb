# %%
# !pip install pdfplumber
# !pip install cohere
# Out:
# Requirement already satisfied: pdfplumber in /usr/local/lib/python3.10/dist-packages (0.11.4)
# Requirement already satisfied: pdfminer.six==20231228 in /usr/local/lib/python3.10/dist-packages (from pdfplumber) (20231228)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from pdfplumber) (11.0.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from pdfplumber) (4.30.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber) (3.4.0)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.22)

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117 --upgrade

# %%
# !pip install langchain einops accelerate transformers bitsandbytes scipy

# %%
# !pip install xformers sentencepiece

# %%
# !pip install -U bitsandbytes

# %%
import gradio as gr
from PyPDF2 import PdfReader
import os
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from nltk.tokenize import sent_tokenize
import cohere
from sklearn.metrics.pairwise import cosine_similarity
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from transformers import AutoTokenizer, AutoModelForCausalLM, TextStreamer, BitsAndBytesConfig
import torch

def load_llama_model():
    name = "meta-llama/Llama-3.1-8B-Instruct"
    auth_token = ""

    # Create tokenizer
    tokenizer = AutoTokenizer.from_pretrained(name, cache_dir='./model/', use_auth_token=auth_token)

    #Load the model with 4-bit quantization using transformers (with bitsandbytes under the hood)
    bnb_config = BitsAndBytesConfig(
        load_in_4bits=True,
        bnb_4bit_use_double_quant=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.bfloat16
    )
  #   bnb_config = BitsAndBytesConfig(
  #   load_in_8bits=True,  # Change to 8-bit quantization
  #   bnb_8bit_use_double_quant=True,  # Optional, use double quantization for better performance
  #   bnb_8bit_quant_type="nf8",  # 8-bit quantization type (you can choose others depending on your needs)
  #   bnb_8bit_compute_dtype=torch.bfloat16  # Use bfloat16 for computation
  # )

    model = AutoModelForCausalLM.from_pretrained(
        name,
        cache_dir='./model/',
        use_auth_token=auth_token,
        torch_dtype=torch.float16,  # Use FP16 precision
        quantization_config=bnb_config,  # 4-bit quantization for reduced memory usage and faster inference
        device_map="auto"  # Automatically map the model to the available GPU (if any)
    )
    return tokenizer, model

def split_into_sentence_chunks(text, max_length):
    """Split text into chunks of sentences with a maximum length."""
    sentences = text.split(". ")
    chunks = []
    current_chunk = ""

    for sentence in sentences:
        if len(current_chunk) + len(sentence) <= max_length:
            current_chunk += sentence + ". "
        else:
            chunks.append(current_chunk.strip())
            current_chunk = sentence + ". "

    if current_chunk:
        chunks.append(current_chunk.strip())

    return chunks

def generate_embedding(text):
    response = cohere_client.embed(texts=[text])
    return response.embeddings[0]

# Function to process PDF files and return the filename with a success message
def process_pdfs(file_list):
    if not file_list:
        return "Please upload a file."

    success_messages = ""
    document_embeddings = []  # Store embeddings here

    for file in file_list:
        # Get just the filename (without path)
        file_name = os.path.basename(file.name)

        # Read the PDF file
        reader = PdfReader(file.name)
        pdf_text = ""
        for page in reader.pages:
            pdf_text += page.extract_text()

        # Add a success message with the filename, append to success_messages
        success_messages += f"'{file_name}' was processed successfully.<br>"

        # Split the text into chunks
        chunk_size = len(pdf_text)//10
        chunks = split_into_sentence_chunks(pdf_text, chunk_size)

        # Generate and store embeddings for the chunks
        document_embeddings.extend([generate_embedding(chunk) for chunk in chunks])

    # Store embeddings internally (e.g., in memory or a database)
    global stored_document_embeddings
    global documents
    documents = chunks
    stored_document_embeddings = document_embeddings

    return success_messages.strip()  # Return only success messages

def get_top_n_relevant_documents(query_embedding, document_embeddings, documents, top_n=3):
    similarities = cosine_similarity([query_embedding], document_embeddings)

    # Get the indices of the top N most similar documents
    top_indices = similarities[0].argsort()[-top_n:][::-1]

    relevant_documents = ""
    details = []

    for idx in top_indices:
        relevant_documents += documents[idx]
        details.append((documents[idx], similarities[0][idx]))

    return relevant_documents, details

def generate_query_embedding(query):
    return generate_embedding(query)

# Function to handle chat input and return a response
def respond_to_user(message, history):
    query_embedding = generate_query_embedding(message)
    relevant_documents, details = get_top_n_relevant_documents(query_embedding, stored_document_embeddings, documents)
    prompt = message+"\nUse these Above Documents and Give me an Answer:\n"+relevant_documents
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    output = model.generate(
        **inputs,
        max_new_tokens=50,  # Limit the number of output tokens (adjust as needed)
        temperature=0.7,    # Control randomness (higher value = more random)
        top_p=0.9,          # Control diversity (higher value = more diverse)
        use_cache=True
    )

    # Decode the generated output tokens to text
    generated_text = tokenizer.decode(output[0], skip_special_tokens=True)

    return generated_text, history



def file_upload_ui():
    with gr.Blocks() as interface:
        gr.Markdown("""### DocuMind \nUpload PDF file, and the chatbot will process their contents.""")

        # File upload section
        with gr.Row():
            pdf_files = gr.File(label="Upload PDFs", file_types=[".pdf"], file_count="multiple")

        submit_button = gr.Button("Process PDFs")
        success_message = gr.Markdown("")  # Placeholder for success message

        # Trigger the process_pdfs function when the button is clicked and update success message
        submit_button.click(process_pdfs, inputs=pdf_files, outputs=success_message)

        # Chat interface for user input
        gr.Markdown("""### Chat with the bot""")

        # Use gr.ChatInterface with the response function
        chatbot = gr.ChatInterface(fn=respond_to_user)

    return interface

# Initialize global variable for embeddings
stored_document_embeddings = []
documents = []

# Launch the Gradio app
if __name__ == "__main__":
    cohere_client = cohere.Client("")
    tokenizer, model = load_llama_model()
    ui = file_upload_ui()
    ui.launch(debug=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py:810: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Unused kwargs: ['load_in_8bits', 'bnb_8bit_use_double_quant', 'bnb_8bit_quant_type', 'bnb_8bit_compute_dtype']. These kwargs are not used in <class 'transformers.utils.quantization_config.BitsAndBytesConfig'>.
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py:471: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/gradio/components/chatbot.py:248: UserWarning: The 'tuples' format for chatbot messages is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#   warnings.warn(
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://cddd807a71da34f811.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://cddd807a71da34f811.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# /usr/local/lib/python3.10/dist-packages/gradio/blocks.py:1780: UserWarning: A function (_submit_fn) returned too many output values (needed: 2, returned: 3). Ignoring extra values.
#     Output components:
#         [state, chatbot]
#     Output values returned:
#         ["What is the Moral Of the story?
# Relevant Documents:
# The sweetness of the fruit tasted even better when shared, and Raju became known as the boy who learned patience.
# Moral: Good things come to those who wait. Patience brings rewards that haste cannot.
# .Late at night, he climbed the tree and ﬁlled his basket with green mangoes.
# The next morning, he eagerly bit into one. To his surprise, it was sour and bitter. He had missed the sweetest part of the mangoes.
# The boy then decided to come back the next day.
# The next day, he ate the mangoes and found that they were sweet and delicious.
# Raju had learned that waiting for a little", [('What is the Moral Of the story?', 'What is the Moral Of the story?\nRelevant Documents:\nThe sweetness of the fruit tasted even better when shared, and Raju became known as the boy who learned patience.\nMoral: Good things come to those who wait. Patience brings rewards that haste cannot.\n.Late at night, he climbed the tree and ﬁlled his basket with green mangoes.\nThe next morning, he eagerly bit into one. To his surprise, it was sour and bitter. He had missed the sweetest part of the mangoes.\nThe boy then decided to come back the next day.\nThe next day, he ate the mangoes and found that they were sweet and delicious.\nRaju had learned that waiting for a little')], []]
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# /usr/local/lib/python3.10/dist-packages/gradio/blocks.py:1780: UserWarning: A function (_submit_fn) returned too many output values (needed: 2, returned: 3). Ignoring extra values.
#     Output components:
#         [state, chatbot]
#     Output values returned:
#         ["Tell me about Raju
# Relevant Documents:
# The villagers forgave him, and Raju learned the value of waiting for the right time.
# From that day on, Raju tended to the tree with care, and when the next season arrived, he shared the ripe, juicy mangoes with everyone.Near his home stood an old mango tree that was famous for bearing the sweetest fruits. Villagers loved the tree, and they always waited patiently for the mangoes to ripen.
# One day, Raju grew impatient. He wanted to taste the mangoes sooner, so he plucked a few unripe ones and ate them. But they were sour and not enjoyable.
# The villagers saw Raju eating the unripe mangoes and were disappointed in him. They thought he", [('Tell me about Raju', 'Tell me about Raju\nRelevant Documents:\nThe villagers forgave him, and Raju learned the value of waiting for the right time.\nFrom that day on, Raju tended to the tree with care, and when the next season arrived, he shared the ripe, juicy mangoes with everyone.Near his home stood an old mango tree that was famous for bearing the sweetest fruits. Villagers loved the tree, and they always waited patiently for the mangoes to ripen.\nOne day, Raju grew impatient. He wanted to taste the mangoes sooner, so he plucked a few unripe ones and ate them. But they were sour and not enjoyable.\nThe villagers saw Raju eating the unripe mangoes and were disappointed in him. They thought he')], []]
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# /usr/local/lib/python3.10/dist-packages/gradio/blocks.py:1780: UserWarning: A function (_submit_fn) returned too many output values (needed: 2, returned: 3). Ignoring extra values.
#     Output components:
#         [state, chatbot]
#     Output values returned:
#         ["Tell me moral of the story?
# Relevant Documents:
# The sweetness of the fruit tasted even better when shared, and Raju became known as the boy who learned patience.
# Moral: Good things come to those who wait. Patience brings rewards that haste cannot.
# .Late at night, he climbed the tree and ﬁlled his basket with green mangoes.
# The next morning, he eagerly bit into one. To his surprise, it was sour and bitter. He had bitten into a green mango.
# He decided to wait and see when the mango would turn ripe.
# Days passed, and the mangoes became ripe.
# He waited for the right moment to pluck and enjoy them.
# One day, he climbed the", [('Tell me about Raju', 'Tell me about Raju\nRelevant Documents:\nThe villagers forgave him, and Raju learned the value of waiting for the right time.\nFrom that day on, Raju tended to the tree with care, and when the next season arrived, he shared the ripe, juicy mangoes with everyone.Near his home stood an old mango tree that was famous for bearing the sweetest fruits. Villagers loved the tree, and they always waited patiently for the mangoes to ripen.\nOne day, Raju grew impatient. He wanted to taste the mangoes sooner, so he plucked a few unripe ones and ate them. But they were sour and not enjoyable.\nThe villagers saw Raju eating the unripe mangoes and were disappointed in him. They thought he'), ('Tell me moral of the story?', 'Tell me moral of the story?\nRelevant Documents:\nThe sweetness of the fruit tasted even better when shared, and Raju became known as the boy who learned patience.\nMoral: Good things come to those who wait. Patience brings rewards that haste cannot.\n.Late at night, he climbed the tree and ﬁlled his basket with green mangoes.\nThe next morning, he eagerly bit into one. To his surprise, it was sour and bitter. He had bitten into a green mango.\nHe decided to wait and see when the mango would turn ripe.\nDays passed, and the mangoes became ripe.\nHe waited for the right moment to pluck and enjoy them.\nOne day, he climbed the')], [['Tell me about Raju', 'Tell me about Raju\nRelevant Documents:\nThe villagers forgave him, and Raju learned the value of waiting for the right time.\nFrom that day on, Raju tended to the tree with care, and when the next season arrived, he shared the ripe, juicy mangoes with everyone.Near his home stood an old mango tree that was famous for bearing the sweetest fruits. Villagers loved the tree, and they always waited patiently for the mangoes to ripen.\nOne day, Raju grew impatient. He wanted to taste the mangoes sooner, so he plucked a few unripe ones and ate them. But they were sour and not enjoyable.\nThe villagers saw Raju eating the unripe mangoes and were disappointed in him. They thought he']]]
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# /usr/local/lib/python3.10/dist-packages/gradio/blocks.py:1780: UserWarning: A function (_submit_fn) returned too many output values (needed: 2, returned: 3). Ignoring extra values.
#     Output components:
#         [state, chatbot]
#     Output values returned:
#         ["Tell me about Mangoes in the story?
# Relevant Documents:
# Near his home stood an old mango tree that was famous for bearing the sweetest fruits. Villagers loved the tree, and they always waited patiently for the mangoes to ripen.
# One day, Raju grew impatient.So, he buried the unripe mangoes behind his house, hoping no one would ﬁnd out.
# A week later, the mango tree began shedding its leaves, and the villagers noticed that fewer mangoes were left on the branches. Raju had to confess to his family that he had buried the mangoes.
# Raju had to go to the village to buy mangoes from the market, which was a big expense. He had to spend a lot of money on mangoes from", [('Tell me about Raju', 'Tell me about Raju\nRelevant Documents:\nThe villagers forgave him, and Raju learned the value of waiting for the right time.\nFrom that day on, Raju tended to the tree with care, and when the next season arrived, he shared the ripe, juicy mangoes with everyone.Near his home stood an old mango tree that was famous for bearing the sweetest fruits. Villagers loved the tree, and they always waited patiently for the mangoes to ripen.\nOne day, Raju grew impatient. He wanted to taste the mangoes sooner, so he plucked a few unripe ones and ate them. But they were sour and not enjoyable.\nThe villagers saw Raju eating the unripe mangoes and were disappointed in him. They thought he'), ('Tell me moral of the story?', 'Tell me moral of the story?\nRelevant Documents:\nThe sweetness of the fruit tasted even better when shared, and Raju became known as the boy who learned patience.\nMoral: Good things come to those who wait. Patience brings rewards that haste cannot.\n.Late at night, he climbed the tree and ﬁlled his basket with green mangoes.\nThe next morning, he eagerly bit into one. To his surprise, it was sour and bitter. He had bitten into a green mango.\nHe decided to wait and see when the mango would turn ripe.\nDays passed, and the mangoes became ripe.\nHe waited for the right moment to pluck and enjoy them.\nOne day, he climbed the'), ('Tell me about Mangoes in the story?', 'Tell me about Mangoes in the story?\nRelevant Documents:\nNear his home stood an old mango tree that was famous for bearing the sweetest fruits. Villagers loved the tree, and they always waited patiently for the mangoes to ripen.\nOne day, Raju grew impatient.So, he buried the unripe mangoes behind his house, hoping no one would ﬁnd out.\nA week later, the mango tree began shedding its leaves, and the villagers noticed that fewer mangoes were left on the branches. Raju had to confess to his family that he had buried the mangoes.\nRaju had to go to the village to buy mangoes from the market, which was a big expense. He had to spend a lot of money on mangoes from')], [['Tell me about Raju', 'Tell me about Raju\nRelevant Documents:\nThe villagers forgave him, and Raju learned the value of waiting for the right time.\nFrom that day on, Raju tended to the tree with care, and when the next season arrived, he shared the ripe, juicy mangoes with everyone.Near his home stood an old mango tree that was famous for bearing the sweetest fruits. Villagers loved the tree, and they always waited patiently for the mangoes to ripen.\nOne day, Raju grew impatient. He wanted to taste the mangoes sooner, so he plucked a few unripe ones and ate them. But they were sour and not enjoyable.\nThe villagers saw Raju eating the unripe mangoes and were disappointed in him. They thought he'], ['Tell me moral of the story?', 'Tell me moral of the story?\nRelevant Documents:\nThe sweetness of the fruit tasted even better when shared, and Raju became known as the boy who learned patience.\nMoral: Good things come to those who wait. Patience brings rewards that haste cannot.\n.Late at night, he climbed the tree and ﬁlled his basket with green mangoes.\nThe next morning, he eagerly bit into one. To his surprise, it was sour and bitter. He had bitten into a green mango.\nHe decided to wait and see when the mango would turn ripe.\nDays passed, and the mangoes became ripe.\nHe waited for the right moment to pluck and enjoy them.\nOne day, he climbed the']]]
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# /usr/local/lib/python3.10/dist-packages/gradio/blocks.py:1780: UserWarning: A function (_submit_fn) returned too many output values (needed: 2, returned: 3). Ignoring extra values.
#     Output components:
#         [state, chatbot]
#     Output values returned:
#         ["What was the key event in World War 2?
# Relevant Documents:
# World War II: A Brief Overview
#
# World War II (1939 –1945) was a global conflict that reshaped the modern world.Major Events
#
# Early Axis Victories: Germany ’s blitzkrieg tactics swiftly overran much of Europe, including France.
#
# The Battle of Britain: Britain ’s defense against the German air force was a turning point in the war, with the British Royal Air Force (RAF) successfully repelling the German air force.
#
# The Invasion of the Soviet Union", [('Tell me about Raju', 'Tell me about Raju\nRelevant Documents:\nThe villagers forgave him, and Raju learned the value of waiting for the right time.\nFrom that day on, Raju tended to the tree with care, and when the next season arrived, he shared the ripe, juicy mangoes with everyone.Near his home stood an old mango tree that was famous for bearing the sweetest fruits. Villagers loved the tree, and they always waited patiently for the mangoes to ripen.\nOne day, Raju grew impatient. He wanted to taste the mangoes sooner, so he plucked a few unripe ones and ate them. But they were sour and not enjoyable.\nThe villagers saw Raju eating the unripe mangoes and were disappointed in him. They thought he'), ('Tell me moral of the story?', 'Tell me moral of the story?\nRelevant Documents:\nThe sweetness of the fruit tasted even better when shared, and Raju became known as the boy who learned patience.\nMoral: Good things come to those who wait. Patience brings rewards that haste cannot.\n.Late at night, he climbed the tree and ﬁlled his basket with green mangoes.\nThe next morning, he eagerly bit into one. To his surprise, it was sour and bitter. He had bitten into a green mango.\nHe decided to wait and see when the mango would turn ripe.\nDays passed, and the mangoes became ripe.\nHe waited for the right moment to pluck and enjoy them.\nOne day, he climbed the'), ('Tell me about Mangoes in the story?', 'Tell me about Mangoes in the story?\nRelevant Documents:\nNear his home stood an old mango tree that was famous for bearing the sweetest fruits. Villagers loved the tree, and they always waited patiently for the mangoes to ripen.\nOne day, Raju grew impatient.So, he buried the unripe mangoes behind his house, hoping no one would ﬁnd out.\nA week later, the mango tree began shedding its leaves, and the villagers noticed that fewer mangoes were left on the branches. Raju had to confess to his family that he had buried the mangoes.\nRaju had to go to the village to buy mangoes from the market, which was a big expense. He had to spend a lot of money on mangoes from'), ('What was the key event in World War 2?', 'What was the key event in World War 2?\nRelevant Documents:\nWorld War II: A Brief Overview  \n \nWorld War II (1939 –1945) was a global conflict that reshaped the modern world.Major Events  \n \nEarly Axis Victories: Germany ’s blitzkrieg tactics swiftly overran much of Europe, including France.  \n \nThe Battle of Britain: Britain ’s defense against the German air force was a turning point in the war, with the British Royal Air Force (RAF) successfully repelling the German air force.  \n \nThe Invasion of the Soviet Union')], [['Tell me about Raju', 'Tell me about Raju\nRelevant Documents:\nThe villagers forgave him, and Raju learned the value of waiting for the right time.\nFrom that day on, Raju tended to the tree with care, and when the next season arrived, he shared the ripe, juicy mangoes with everyone.Near his home stood an old mango tree that was famous for bearing the sweetest fruits. Villagers loved the tree, and they always waited patiently for the mangoes to ripen.\nOne day, Raju grew impatient. He wanted to taste the mangoes sooner, so he plucked a few unripe ones and ate them. But they were sour and not enjoyable.\nThe villagers saw Raju eating the unripe mangoes and were disappointed in him. They thought he'], ['Tell me moral of the story?', 'Tell me moral of the story?\nRelevant Documents:\nThe sweetness of the fruit tasted even better when shared, and Raju became known as the boy who learned patience.\nMoral: Good things come to those who wait. Patience brings rewards that haste cannot.\n.Late at night, he climbed the tree and ﬁlled his basket with green mangoes.\nThe next morning, he eagerly bit into one. To his surprise, it was sour and bitter. He had bitten into a green mango.\nHe decided to wait and see when the mango would turn ripe.\nDays passed, and the mangoes became ri ...
#   warnings.warn(
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://cddd807a71da34f811.gradio.live

# %%
import gradio as gr
from PyPDF2 import PdfReader
import os
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from nltk.tokenize import sent_tokenize
import cohere
from sklearn.metrics.pairwise import cosine_similarity
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
import torch


# Load the LLaMA model
def load_llama_model():
    name = "meta-llama/Llama-3.1-8B-Instruct"
    auth_token = "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"

    # Create tokenizer
    tokenizer = AutoTokenizer.from_pretrained(name, cache_dir='./model/', use_auth_token=auth_token)

    # Load the model with 4-bit quantization using transformers (with bitsandbytes under the hood)
    bnb_config = BitsAndBytesConfig(
        load_in_4bits=True,
        bnb_4bit_use_double_quant=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.bfloat16
    )

    model = AutoModelForCausalLM.from_pretrained(
        name,
        cache_dir='./model/',
        use_auth_token=auth_token,
        torch_dtype=torch.float16,  # Use FP16 precision
        quantization_config=bnb_config,  # 4-bit quantization for reduced memory usage and faster inference
        device_map="auto"  # Automatically map the model to the available GPU (if any)
    )
    return tokenizer, model


# Split text into chunks based on maximum length
def split_into_sentence_chunks(text, max_length):
    """Split text into chunks of sentences with a maximum length."""
    sentences = text.split(". ")
    chunks = []
    current_chunk = ""

    for sentence in sentences:
        if len(current_chunk) + len(sentence) <= max_length:
            current_chunk += sentence + ". "
        else:
            chunks.append(current_chunk.strip())
            current_chunk = sentence + ". "

    if current_chunk:
        chunks.append(current_chunk.strip())

    return chunks


# Generate embeddings using Cohere API
def generate_embedding(text):
    response = cohere_client.embed(texts=[text])
    return response.embeddings[0]


# Process PDF files and extract embeddings
def process_pdfs(file_list):
    if not file_list:
        return "Please upload a file."

    success_messages = ""
    document_embeddings = []  # Store embeddings here

    for file in file_list:
        # Get just the filename (without path)
        file_name = os.path.basename(file.name)

        # Read the PDF file
        reader = PdfReader(file.name)
        pdf_text = ""
        for page in reader.pages:
            pdf_text += page.extract_text()

        # Add a success message with the filename
        success_messages += f"'{file_name}' was processed successfully.<br>"

        # Split the text into chunks
        chunk_size = 300  # Adjust chunk size based on document content
        chunks = split_into_sentence_chunks(pdf_text, chunk_size)

        # Generate and store embeddings for the chunks
        document_embeddings.extend([generate_embedding(chunk) for chunk in chunks])

    # Store embeddings internally (e.g., in memory or a database)
    global stored_document_embeddings
    global documents
    documents = chunks
    stored_document_embeddings = document_embeddings

    return success_messages.strip()  # Return only success messages


# Get top N relevant documents based on cosine similarity
def get_top_n_relevant_documents(query_embedding, document_embeddings, documents, top_n=3):
    similarities = cosine_similarity([query_embedding], document_embeddings)

    # Get the indices of the top N most similar documents
    top_indices = similarities[0].argsort()[-top_n:][::-1]

    relevant_documents = ""
    details = []

    for idx in top_indices:
        relevant_documents += documents[idx] + "\n"
        details.append((documents[idx], similarities[0][idx]))

    return relevant_documents, details


# Generate embeddings for a query
def generate_query_embedding(query):
    return generate_embedding(query)


# Handle chat input and return a response
def respond_to_user(message, history):
    query_embedding = generate_query_embedding(message)
    relevant_documents, details = get_top_n_relevant_documents(query_embedding, stored_document_embeddings, documents)

    # Improved prompt with clear instructions
    prompt = (
        f"The following documents contain useful information:\n\n"
        f"{relevant_documents}\n\n"
        f"User's Question:\n{message}\n\n"
        f"Please provide a detailed answer based on the above information."
    )

    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    output = model.generate(
        **inputs,
        max_new_tokens=len(prompt)+100,  # Increased token limit
        temperature=0.7,
        top_p=0.9,
        use_cache=True
    )

    # Decode and clean the generated output
    generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
    final_answer = generated_text.replace(relevant_documents, "").strip()

    return final_answer, history


# Create Gradio UI for uploading PDFs and chatting
def file_upload_ui():
    with gr.Blocks() as interface:
        gr.Markdown("""### DocuMind \nUpload PDF files, and the chatbot will process their contents.""")

        # File upload section
        with gr.Row():
            pdf_files = gr.File(label="Upload PDFs", file_types=[".pdf"], file_count="multiple")

        submit_button = gr.Button("Process PDFs")
        success_message = gr.Markdown("")  # Placeholder for success message

        # Trigger the process_pdfs function when the button is clicked and update success message
        submit_button.click(process_pdfs, inputs=pdf_files, outputs=success_message)

        # Chat interface for user input
        gr.Markdown("""### Chat with the bot""")

        # Use gr.ChatInterface with the response function
        chatbot = gr.ChatInterface(fn=respond_to_user)

    return interface


# Initialize global variable for embeddings
stored_document_embeddings = []
documents = []

# Launch the Gradio app
if __name__ == "__main__":
    cohere_client = cohere.Client("vALklAqosIuoSOWurnZYy3SZMmMwdW3nSQKq25OG")
    tokenizer, model = load_llama_model()
    ui = file_upload_ui()
    ui.launch(debug=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py:810: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Unused kwargs: ['load_in_4bits']. These kwargs are not used in <class 'transformers.utils.quantization_config.BitsAndBytesConfig'>.
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py:471: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/gradio/components/chatbot.py:248: UserWarning: The 'tuples' format for chatbot messages is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#   warnings.warn(
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://7fc9b1d97920a0040a.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://7fc9b1d97920a0040a.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# /usr/local/lib/python3.10/dist-packages/gradio/blocks.py:1780: UserWarning: A function (_submit_fn) returned too many output values (needed: 2, returned: 3). Ignoring extra values.
#     Output components:
#         [state, chatbot]
#     Output values returned:
#         ["The following documents contain useful information:
#
# Consequences
#
# World War  II caused immense devastation, with an estimated 70 -85 million deaths, including six
# million Jews killed in the Holocaust. Entire cities were destroyed, and economies lay in ruins.
# World War II: A Brief Overview
#
# World War II (1939 –1945) was a global conflict that reshaped the modern world. Spanning six years,
# it involved more than 30 countries and resulted in unprecedented destruction and loss of life.
# World War II remains a pivotal chapter in human history, offering lessons on the consequences of
# unchecked aggression and the importance of international cooperation. Its impact continues to
# shape global politics and society today.
# .
#
#
# User's Question:
# Tell Me About the consequences Of World War 2?
#
# Please provide a detailed answer based on the above information.
#
# Answer:
# The consequences of World War II were immense and far-reaching. Some of the key consequences include:
#
# *   **Massive loss of life**: An estimated 70-85 million deaths, including six million Jews killed in the Holocaust, making it one of the deadliest conflicts in human history.
# *   **Destruction of cities and infrastructure**: Entire cities were destroyed, leaving millions of people homeless and without access to basic necessities like food, water, and shelter.
# *   **Economic devastation**: Economies of many countries were severely impacted, leading to widespread poverty, unemployment, and economic instability.
# *   **Reshaping of the modern world**: The war led to a significant shift in the global balance of power, with the emergence of the United States and the Soviet Union as superpowers.
# *   **Lessons on unchecked aggression**: The war highlighted the dangers of unchecked aggression and the importance of international cooperation in preventing future conflicts.
# *   **Lasting impact on global politics and society**: The consequences of World War II continue to shape global politics and society today, with ongoing efforts to promote peace, security, and cooperation among nations.
#
# In summary, the consequences of World War II were profound and have had a lasting impact on the world. It is essential to learn from the lessons of history and work towards preventing similar conflicts in the future.", [('Tell Me About the consequences Of World War 2?', "The following documents contain useful information:\n\nConsequences  \n \nWorld War  II caused immense devastation, with an estimated 70 -85 million deaths, including six \nmillion Jews killed in the Holocaust. Entire cities were destroyed, and economies lay in ruins.\nWorld War II: A Brief Overview  \n \nWorld War II (1939 –1945) was a global conflict that reshaped the modern world. Spanning six years, \nit involved more than 30 countries and resulted in unprecedented destruction and loss of life.\nWorld War II remains a pivotal chapter in human history, offering lessons on the consequences of \nunchecked aggression and the importance of international cooperation. Its impact continues to \nshape global politics and society today.  \n.\n\n\nUser's Question:\nTell Me About the consequences Of World War 2?\n\nPlease provide a detailed answer based on the above information. \n\nAnswer:\nThe consequences of World War II were immense and far-reaching. Some of the key consequences include:\n\n*   **Massive loss of life**: An estimated 70-85 million deaths, including six million Jews killed in the Holocaust, making it one of the deadliest conflicts in human history.\n*   **Destruction of cities and infrastructure**: Entire cities were destroyed, leaving millions of people homeless and without access to basic necessities like food, water, and shelter.\n*   **Economic devastation**: Economies of many countries were severely impacted, leading to widespread poverty, unemployment, and economic instability.\n*   **Reshaping of the modern world**: The war led to a significant shift in the global balance of power, with the emergence of the United States and the Soviet Union as superpowers.\n*   **Lessons on unchecked aggression**: The war highlighted the dangers of unchecked aggression and the importance of international cooperation in preventing future conflicts.\n*   **Lasting impact on global politics and society**: The consequences of World War II continue to shape global politics and society today, with ongoing efforts to promote peace, security, and cooperation among nations.\n\nIn summary, the consequences of World War II were profound and have had a lasting impact on the world. It is essential to learn from the lessons of history and work towards preventing similar conflicts in the future.")], []]
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# /usr/local/lib/python3.10/dist-packages/gradio/blocks.py:1780: UserWarning: A function (_submit_fn) returned too many output values (needed: 2, returned: 3). Ignoring extra values.
#     Output components:
#         [state, chatbot]
#     Output values returned:
#         ["The following documents contain useful information:
#
#
#
# User's Question:
# What role did Japan Have?
#
# Please provide a detailed answer based on the above information.
#
# Answer:
# According to the information, Japan played a significant role in the World War II. Japan expanded across the Pacific, occupying territories like the Philippines and Malaya. This indicates that Japan was an expansionist power during this period. The invasion of Manchuria, a region in northeastern China, was also mentioned as a key event that heightened tensions leading to the war.
#
# However, Japan's role in the war was ultimately limited by the atomic bombings of Hiroshima and Nagasaki, which led to its surrender and the end of the war. This suggests that Japan's aggressive policies and expansionist ambitions were ultimately checked by the Allied powers.
#
# Therefore, the role of Japan in World War II can be summarized as follows:
#
# *   Expansionist power that occupied territories in the Pacific
# *   Key player in the conflict, particularly in the early years
# *   Ultimately defeated by the Allied powers through the atomic bombings of Hiroshima and Nagasaki.
#
# The provided information does not provide a detailed timeline of Japan's role in the war, but it highlights the significance of the country's actions during this period.  Japan's actions had a significant impact on the course of the war, and its ultimate defeat marked the end of the conflict.
#
# The information also mentions that Japan's expansionist ambitions and aggressive policies heightened tensions leading to the war, which is a key aspect of the country's role in the conflict.
#
# Overall, the role of Japan in World War II was complex and multifaceted, involving both expansionist ambitions and a significant impact on the course of the war.  Its ultimate defeat marked the end of the conflict and had a lasting impact on the world.
#
# Japan's actions during this period were a key factor in the outbreak and course of the war, and its legacy continues to be felt today.
#
# The provided information highlights the significance of Japan's role in the war and provides a useful starting point for further research and analysis.
#
# The information also mentions that the Battle of Midway marked a turning point in the Pacific theater, which is a key aspect of the war.
#
# The provided information is a useful summary of Japan's role in the war and highlights the significance of the country's actions during this period.
#
# The information also mentions that the United States dropped atomic bombs on Hiroshima and Nagasaki, which led to Japan's surrender and the end of the war.
#
# The provided information is a useful summary of the key events and turning points in the war, including Japan's role in the conflict.
#
# The information also highlights the significance of the atomic bombings of Hiroshima and Nagasaki, which marked the end of the war.
#
# The provided information is a useful summary of the key events and turning points in the war, including Japan's role in the conflict.
#
# The information also mentions that the Allied powers ultimately defeated Japan through the atomic bombings of Hiroshima and Nagasaki.
#
# The provided information is a useful summary of the key events and turning points in the war, including Japan's role in the conflict.
#
# The information also highlights the significance of the atomic bombings of Hiroshima and Nagasaki, which marked the end of the war.
#
# The provided information is a useful summary of the key events and turning points in the war, including Japan's role in the conflict.
#
# The information also mentions that the Allied powers ultimately defeated Japan through the atomic bombings of Hiroshima and Nagasaki.
#
# The provided information is a useful summary of the key events and turning points in the war, including Japan's role in the conflict.
#
# The information also highlights the significance of the atomic bombings of Hiroshima and Nagasaki, which marked the end of the war.
#
# The provided information is a useful summary of the key events and turning points in the war, including Japan's role in the conflict.
#
# The information also mentions that the Allied powers ultimately defeated Japan through the atomic bombings of Hiroshima and Nagasaki.
#
# The provided information is a useful summary of the key events and turning points in the war, including Japan's role in the conflict.
#
# The information also highlights the significance of the atomic bombings of Hiroshima and Nagasaki, which marked the end of the war.
#
# The provided information is a useful summary of the key events and turning points in the war, including Japan's role in the conflict.
#
# The information also mentions that the Allied powers ultimately defeated Japan through the atomic bombings of Hiroshima and Nagasaki.
#
# The provided information is a useful summary of the key events and turning points in the war, including Japan's role in the conflict.
#
# The information also highlights the significance of the atomic bombings of Hiroshima and Nagasaki, which marked the end of the war.
#
# The provided information is a useful summary of the key events and turning points in the war, including Japan's role in the conflict.
#
# The information also mentions that", [('Tell Me About the consequences Of World War 2?', "The following documents contain useful information:\n\nConsequences  \n \nWorld War  II caused immense devastation, with an estimated 70 -85 million deaths, including six \nmillion Jews killed in the Holocaust. Entire cities were destroyed, and economies lay in ruins.\nWorld War II: A Brief Overview  \n \nWorld War II (1939 –1945) was a global conflict that reshaped the modern world. Spanning six years, \nit involved more than 30 countries and resulted in unprecedented destruction and loss of life.\nWorld War II remains a pivotal chapter in human history, offering lessons on the consequences of \nunchecked aggression and the importance of international cooperation. Its impact continues to \nshape global politics and society today.  \n.\n\n\nUser's Question:\nTell Me About the consequences Of World War 2?\n\nPlease provide a detailed answer based on the above information. \n\nAnswer:\nThe consequences of World War II were immense and far-reaching. Some of the key consequences include:\n\n*   **Massive loss of life**: An estimated 70-85 million deaths, including six million Jews killed in the Holocaust, making it one of the deadliest conflicts in human history.\n*   **Destruction of cities and infrastructure**: Entire cities were destroyed, leaving millions of people homeless and without access to basic necessities like food, water, and shelter.\n*   **Economic devastation**: Economies of many countries were severely impacted, leading to widespread poverty, unemployment, and economic instability.\n*   **Reshaping of the modern world**: The war led to a significant shift in the global balance of power, with the emergence of the United States and the Soviet Union as superpowers.\n*   **Lessons on unchecked aggression**: The war highlighted the dangers of unchecked aggression and the importance of international cooperation in preventing future conflicts.\n*   **Lasting impact on global politics and society**: The consequences of World War II continue to shape global politics and society today, with ongoing efforts to promote peace, security, and cooperation among nations.\n\nIn summary, the consequences of World War II were profound and have had a lasting impact on the world. It is essential to learn from the lessons of history and work towards preventing similar conflicts in the future."), ('What role did Japan Have ?', "The following documents contain useful information:\n\n\n\nUser's Question:\nWhat role did Japan Have?\n\nPlease provide a detailed answer based on the above information. \n\nAnswer:\nAccording to the information, Japan played a significant role in the World War II. Japan expanded across the Pacific, occupying territories like the Philippines and Malaya. This indicates that Japan was an expansionist power during this period. The invasion of Manchuria, a region in northeastern China, was also mentioned as a key event that heightened tensions leading to the war.\n\nHowever, Japan's role in the war was ultimately limited by the atomic bombings of Hiroshima and Nagasaki, which led to its surrender and the end of the war. This suggests that Japan's aggressive policies and expansionist ambitions were ultimately checked by the Allied powers.\n\nTherefore, the role of Japan in World War II can be summarized as follows:\n\n*   Expansionist power that occupied territories in the Pacific\n*   Key player in the conflict, particularly in the early years\n*   Ultimately defeated by the Allied powers through the atomic bombings of Hiroshima and Nagasaki. \n\nThe provided information does not provide a detailed timeline of Japan's role in the war, but it highlights the significance of the country's actions during this period.  Japan's actions had a significant impact on the course of the war, and its ultimate defeat marked the end of the conflict. \n\nThe information also mentions that Japan's expansionist ambitions and aggressive policies h ...
#   warnings.warn(
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://7fc9b1d97920a0040a.gradio.live

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 17.2 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

# Run the model to generate the output
output = model.generate(
    **inputs,
    max_new_tokens=50,  # Limit the number of output tokens (adjust as needed)
    temperature=0.7,    # Control randomness (higher value = more random)
    top_p=0.9,          # Control diversity (higher value = more diverse)
    use_cache=True
)

# %%
# Decode the generated output tokens to text
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)

# Print the generated output
print(generated_text)

# %%
# !pip install pdfplumber
# !pip install nltk
# !pip install cohere
